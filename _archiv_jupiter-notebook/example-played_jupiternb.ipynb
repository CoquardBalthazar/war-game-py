# %%
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

class Card():
	'''
	A class that allows the creation of card, by giving their suit and their ranks. Based on the rank, the value of the card is also given
	''' 
	
	def __init__(self, suit, rank):
		self.suit = suit
		self.rank = rank
		self.value = values[rank]
		
		# print(f'{rank} of {suit} created.')
		# With one card created it is interesting, but when creating a deck its problematic

	def __str__ (self):
		return self.rank + " of " + self.suit


class Deck():

	'''
	A class that allows the creation of a deck. The deck is created based on the Card() class. 
	We can perform 2 operations with the deck : shuffle the deck, deal on card of the back of deck
	'''

	def __init__(self):
		self.all_cards = []
		# An empty deck that we are going to fill. NOTE : Thanks to this attribute we can then check the length of the deck. deck.cards_deck

		for suit in suits :
			for rank in ranks :
				created_card = Card(suit, rank)
				self.all_cards.append(created_card)
		# Iteration through the 2 lists in 1st indentation (suits, ranks). Creation of the card with the class Card() and add the card to the empty deck. #

	def deal_one(self):
		return self.all_cards.pop()
		# NOTE : important to return the result. If not it will not be saved, which would be a problem when playing the game

	def shuffle(self, amount=3):
		for i in range(amount):
			random.shuffle(self.all_cards)
		# NOTE : important to call shuffle from the library random & to say what to shuffle (all_cards.deck) If not it does not work.



class Player():
	''' 
	A class that symbolise the deck of a player / the cards hold by the player.
	'''

	def __init__(self, name):
		self.name = name
		self.all_cards = []

	def __str__(self):
		# A method that returns the name of the player
		return f'{self.name}'

	def number_cards(self):
		# a method that returns the number of cards hold by the player
		return f'{self.name} holds {len(self.all_cards)} cards.'

	def remove_one(self):
		# A method that remove the last card of the player's deck
		return self.all_cards.pop(0)

	def add_cards(self, new_cards):
		# A method that add one or many cards to the bottom of the player's deck
		if type(new_cards) == type([]):
			self.all_cards.extend(new_cards)
		else :
			self.all_cards.append(new_cards)


'''
GAME SET UP --------------------------------------------------------------------------------------------------------------------------
'''
player_human = Player(input('Please Enter your name : ')) #Create the Human player
player_computer = Player('Computer') # Create the Computer player
print(f'The game opposes {player_human} to {player_computer}.')

game_deck = Deck() # create the deck
game_deck.shuffle() # shuffle the deck

# Distribute the cards between the player
for card_distributed in range(26): 
	player_human.add_cards(game_deck.deal_one())
	player_computer.add_cards(game_deck.deal_one())


'''
GAME INSTRUCTIONS / Explain the rules for the game -----------------------------------------------------------------------------------
'''
print(""" 
	W E L C O M E  T O  W A R !

	The rules are simple, play a card and pray to god that it is a 
	higher rank than your opponents card.

	If you play the same card rank as your opponent, it's WAR !
	You and your opponent will play 5 more cards, only the last one
	needs to be higher rank than your opponents second card.
	If it is, you get all the cards played that round.

	If the computer cannot play, you win !

	LET'S BEGIN ! """)
wait = input("press ENTER to start")  # all "wait" variables, are just there to wait for the player to input something

'''
ROUND LOGIC ---------------------------------------------------------------------------------------------------------------------------
'''
round_num = 0
game_on = True

while game_on :
	round_num += 1 #update the round number
	print(f'''
		
	----------------------------------------------------------------------------
	Round {round_num}

	''')

	print(player_human.number_cards()) #print how many card the Human player has
	print(player_computer.number_cards()) #same for the computer player

	''' CHECK IF CARDS REMAINING --------------------------------------------------------'''

	#Check if computer lost
	if len(player_computer.all_cards) == 0 :
		print(f"{player_computer}, you don't have any card left. {player_human} wins !")
		break

	#Check if computer lost
	elif len(player_human.all_cards) == 0 :
		print(f"{player_human}, you don't have any card left. {player_computer} wins !")
		break

	''' START THE ROUND ----------------------------------------------------------------- '''

	print('\nIt is time to play !')

	wait = input('press ENTER to play a card') #Human plays
	player_human_side = []
	player_human_side.append(player_human.remove_one())
	print(f'You played the card {player_human_side[-1]}.')

	player_computer_side = []
	wait = input(f'press ENTER to see what card {player_computer} plays') #Computer plays
	player_computer_side.append(player_computer.remove_one())
	print(f'{player_computer} played {player_computer_side[-1]}.')

	'''
	AT WAR -----------------------------------------------------------------------------------------------------------------------------
	'''
	at_war = True
	
	while at_war:
		# Card Human wins over Card Computer -> Human wins the cards
		if player_human_side[-1].value > player_computer_side[-1].value :
			player_human.add_cards(player_computer_side) #add the card of the opponent
			player_human.add_cards(player_human_side) #add his cards back
			print (player_human.number_cards())
			print (player_computer.number_cards())
			
			at_war = False

		# Card Computer wins over Card Human -> Computer wins the cards
		elif player_human_side[-1].value < player_computer_side[-1].value :
			player_computer.add_cards(player_human_side)#add the card of the opponent
			player_computer.add_cards(player_computer_side) #add its cards back
			print (player_human.number_cards())
			print (player_computer.number_cards())
			
			at_war = False


		else :
			print('\n WAR !!!! \n')
			if len(player_computer.all_cards) <5:
				print ('Computer unable to declare war')
				print (f'{player_human} WINS !')
				break
				game_on = False

			elif len(player_human.all_cards) <5:
				print (f'{player_human} unable to declare war')
				print (f'{player_computer} WINS !')
				break
				game_on = False

			for num in range(5):
				player_human_side.append(player_human.remove_one())
				player_computer_side.append(player_computer.remove_one())























'''
DRAFT Class Table
'''
class Table(Player):
	# A Class that represent the table : 2 opposing sides that can take card, remove card, can be compared, merge.

	def __init__(self):
		self.side_human = []  #Side from the Player human == were the player human plays his cards
		self.side_computer = [] #identical but for the Player computer
		self.all_cards = [] # a list for the cards won in the round

	def __str__ (self): #a methods that prints if the table is empty or not
		if self.side_computer == [] and self.side_human == [] and self.all_cards == [] :
			return 'No cards are on the table'
		else :
			return 'Some cards are on the table'

	def add_cards_side_human(self, new_cards):
		# A method that add one or many cards to the table on as played by the human player

		if type(new_cards) == type([]):
			self.side_human.extend(new_cards)

		else :
			self.side_human.append(new_cards)

	def add_cards_side_computer(self, new_cards):
		# A method that add one or many cards to the table on as played by the human player

		if type(new_cards) == type([]):
			self.side_computer.extend(new_cards)

		else :
			self.side_computer.append(new_cards)

	def compare(self, stack_one, stack_two) : #Method that compare 2 stacks of cards, or more exactly compare the last cards (element [-1]) from the stacks (list).
		if stack_one[-1].value > stack_two[-1].value :
			return 'side_one'

		if stack_one[-1] < stack_two[-1] :
			return 'side_two'
		
		else :
			return 'draw'

	def merge(self, stack_one, stack_two) : #Method that merge two stacks of cards and save them in a last one. It does NOT shuffle.
		new_stack = stack_one.extend(stack_two)
		return new_stack
# Out:
# Please Enter your name : Juliana
# The game opposes Juliana to Computer.
#
# 	W E L C O M E  T O  W A R !
#
# 	The rules are simple, play a card and pray to god that it is a
# 	higher rank than your opponents card.
#
# 	If you play the same card rank as your opponent, it's WAR !
# 	You and your opponent will play 5 more cards, only the last one
# 	needs to be higher rank than your opponents second card.
# 	If it is, you get all the cards played that round.
#
# 	If the computer cannot play, you win !
#
# 	LET'S BEGIN !
# press ENTER to start
#
#
# 	----------------------------------------------------------------------------
# 	Round 1
#
#
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Spades.
# press ENTER to see what card Computer plays
# Computer played Two of Spades.
# Juliana holds 27 cards.
# Computer holds 25 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 2
#
#
# Juliana holds 27 cards.
# Computer holds 25 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Eight of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Ten of Hearts.
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 3
#
#
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Spades.
# press ENTER to see what card Computer plays
# Computer played Six of Diamonds.
#
#  WAR !!!!
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 4
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Eight of Spades.
# press ENTER to see what card Computer plays
# Computer played Five of Diamonds.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 5
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Spades.
# press ENTER to see what card Computer plays
# Computer played Four of Clubs.
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 6
#
#
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card King of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Eight of Hearts.
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 7
#
#
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Clubs.
# press ENTER to see what card Computer plays
# Computer played Three of Spades.
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 8
#
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Three of Diamonds.
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 9
#
#
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Clubs.
# press ENTER to see what card Computer plays
# Computer played Ace of Spades.
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 10
#
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Clubs.
# press ENTER to see what card Computer plays
# Computer played King of Clubs.
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 11
#
#
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Nine of Hearts.
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 12
#
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Clubs.
# press ENTER to see what card Computer plays
# Computer played King of Hearts.
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 13
#
#
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Spades.
# press ENTER to see what card Computer plays
# Computer played Ace of Clubs.
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 14
#
#
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Spades.
# press ENTER to see what card Computer plays
# Computer played Five of Hearts.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 15
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Jack of Clubs.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 16
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Hearts.
# press ENTER to see what card Computer plays
# Computer played Eight of Clubs.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 17
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Clubs.
# press ENTER to see what card Computer plays
# Computer played Three of Clubs.
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 18
#
#
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Hearts.
# press ENTER to see what card Computer plays
# Computer played Queen of Diamonds.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 19
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Hearts.
# press ENTER to see what card Computer plays
# Computer played King of Spades.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 20
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Two of Hearts.
# press ENTER to see what card Computer plays
# Computer played Nine of Spades.
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 21
#
#
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Hearts.
# press ENTER to see what card Computer plays
# Computer played Two of Diamonds.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 22
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Two of Spades.
# press ENTER to see what card Computer plays
# Computer played Eight of Diamonds.
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 23
#
#
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Spades.
# press ENTER to see what card Computer plays
# Computer played Ten of Hearts.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 24
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Six of Clubs.
#
#  WAR !!!!
#
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 25
#
#
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Spades.
# press ENTER to see what card Computer plays
# Computer played Ten of Spades.
# Juliana holds 25 cards.
# Computer holds 27 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 26
#
#
# Juliana holds 25 cards.
# Computer holds 27 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Ace of Clubs.
# Juliana holds 24 cards.
# Computer holds 28 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 27
#
#
# Juliana holds 24 cards.
# Computer holds 28 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Hearts.
# press ENTER to see what card Computer plays
# Computer played Four of Spades.
# Juliana holds 25 cards.
# Computer holds 27 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 28
#
#
# Juliana holds 25 cards.
# Computer holds 27 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Spades.
# press ENTER to see what card Computer plays
# Computer played Five of Hearts.
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 29
#
#
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Hearts.
# press ENTER to see what card Computer plays
# Computer played Nine of Diamonds.
# Juliana holds 25 cards.
# Computer holds 27 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 30
#
#
# Juliana holds 25 cards.
# Computer holds 27 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Spades.
# press ENTER to see what card Computer plays
# Computer played Jack of Clubs.
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 31
#
#
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Three of Hearts.
# Juliana holds 27 cards.
# Computer holds 25 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 32
#
#
# Juliana holds 27 cards.
# Computer holds 25 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Eight of Spades.
# press ENTER to see what card Computer plays
# Computer played Queen of Diamonds.
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 33
#
#
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Clubs.
# press ENTER to see what card Computer plays
# Computer played Four of Hearts.
#
#  WAR !!!!
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 34
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Six of Diamonds.
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 35
#
#
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Seven of Hearts.
#
#  WAR !!!!
#
# Juliana holds 25 cards.
# Computer holds 27 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 36
#
#
# Juliana holds 25 cards.
# Computer holds 27 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Clubs.
# press ENTER to see what card Computer plays
# Computer played Ace of Spades.
# Juliana holds 24 cards.
# Computer holds 28 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 37
#
#
# Juliana holds 24 cards.
# Computer holds 28 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Two of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Nine of Clubs.
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 38
#
#
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Hearts.
# press ENTER to see what card Computer plays
# Computer played King of Clubs.
# Juliana holds 24 cards.
# Computer holds 28 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 39
#
#
# Juliana holds 24 cards.
# Computer holds 28 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Hearts.
# press ENTER to see what card Computer plays
# Computer played Queen of Clubs.
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 40
#
#
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Spades.
# press ENTER to see what card Computer plays
# Computer played King of Hearts.
# Juliana holds 22 cards.
# Computer holds 30 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 41
#
#
# Juliana holds 22 cards.
# Computer holds 30 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Spades.
# press ENTER to see what card Computer plays
# Computer played Six of Spades.
# Juliana holds 21 cards.
# Computer holds 31 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 42
#
#
# Juliana holds 21 cards.
# Computer holds 31 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Hearts.
# press ENTER to see what card Computer plays
# Computer played Ten of Spades.
# Juliana holds 22 cards.
# Computer holds 30 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 43
#
#
# Juliana holds 22 cards.
# Computer holds 30 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Hearts.
# press ENTER to see what card Computer plays
# Computer played Four of Diamonds.
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 44
#
#
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Spades.
# press ENTER to see what card Computer plays
# Computer played Ace of Clubs.
# Juliana holds 22 cards.
# Computer holds 30 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 45
#
#
# Juliana holds 22 cards.
# Computer holds 30 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Clubs.
# press ENTER to see what card Computer plays
# Computer played Six of Hearts.
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 46
#
#
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Spades.
# press ENTER to see what card Computer plays
# Computer played Nine of Diamonds.
# Juliana holds 24 cards.
# Computer holds 28 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 47
#
#
# Juliana holds 24 cards.
# Computer holds 28 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Hearts.
# press ENTER to see what card Computer plays
# Computer played Eight of Spades.
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 48
#
#
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Queen of Diamonds.
# Juliana holds 22 cards.
# Computer holds 30 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 49
#
#
# Juliana holds 22 cards.
# Computer holds 30 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Hearts.
# press ENTER to see what card Computer plays
# Computer played Three of Diamonds.
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 50
#
#
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card King of Spades.
# press ENTER to see what card Computer plays
# Computer played Six of Diamonds.
# Juliana holds 24 cards.
# Computer holds 28 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 51
#
#
# Juliana holds 24 cards.
# Computer holds 28 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Two of Hearts.
# press ENTER to see what card Computer plays
# Computer played Seven of Diamonds.
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 52
#
#
# Juliana holds 23 cards.
# Computer holds 29 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Spades.
# press ENTER to see what card Computer plays
# Computer played Nine of Hearts.
#
#  WAR !!!!
#
# Juliana holds 29 cards.
# Computer holds 23 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 53
#
#
# Juliana holds 29 cards.
# Computer holds 23 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card King of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Five of Clubs.
# Juliana holds 30 cards.
# Computer holds 22 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 54
#
#
# Juliana holds 30 cards.
# Computer holds 22 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Spades.
# press ENTER to see what card Computer plays
# Computer played Ace of Diamonds.
# Juliana holds 29 cards.
# Computer holds 23 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 55
#
#
# Juliana holds 29 cards.
# Computer holds 23 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Clubs.
# press ENTER to see what card Computer plays
# Computer played Ten of Diamonds.
#
#  WAR !!!!
#
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 56
#
#
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Hearts.
# press ENTER to see what card Computer plays
# Computer played Nine of Clubs.
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 57
#
#
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Hearts.
# press ENTER to see what card Computer plays
# Computer played Ten of Hearts.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 58
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Clubs.
# press ENTER to see what card Computer plays
# Computer played Queen of Clubs.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 59
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Jack of Spades.
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 60
#
#
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Spades.
# press ENTER to see what card Computer plays
# Computer played King of Hearts.
# Juliana holds 30 cards.
# Computer holds 22 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 61
#
#
# Juliana holds 30 cards.
# Computer holds 22 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Four of Spades.
# Juliana holds 29 cards.
# Computer holds 23 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 62
#
#
# Juliana holds 29 cards.
# Computer holds 23 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Hearts.
# press ENTER to see what card Computer plays
# Computer played Six of Spades.
# Juliana holds 28 cards.
# Computer holds 24 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 63
#
#
# Juliana holds 28 cards.
# Computer holds 24 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Seven of Spades.
# Juliana holds 27 cards.
# Computer holds 25 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 64
#
#
# Juliana holds 27 cards.
# Computer holds 25 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card King of Spades.
# press ENTER to see what card Computer plays
# Computer played Ace of Clubs.
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 65
#
#
# Juliana holds 26 cards.
# Computer holds 26 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Hearts.
# press ENTER to see what card Computer plays
# Computer played Three of Hearts.
# Juliana holds 27 cards.
# Computer holds 25 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 66
#
#
# Juliana holds 27 cards.
# Computer holds 25 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Eight of Spades.
# Juliana holds 28 cards.
# Computer holds 24 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 67
#
#
# Juliana holds 28 cards.
# Computer holds 24 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Eight of Clubs.
# press ENTER to see what card Computer plays
# Computer played Five of Diamonds.
# Juliana holds 29 cards.
# Computer holds 23 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 68
#
#
# Juliana holds 29 cards.
# Computer holds 23 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Hearts.
# press ENTER to see what card Computer plays
# Computer played Queen of Diamonds.
#
#  WAR !!!!
#
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 69
#
#
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Clubs.
# press ENTER to see what card Computer plays
# Computer played Nine of Clubs.
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 70
#
#
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Spades.
# press ENTER to see what card Computer plays
# Computer played Six of Hearts.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 71
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Eight of Hearts.
# press ENTER to see what card Computer plays
# Computer played Ten of Hearts.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 72
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Clubs.
# press ENTER to see what card Computer plays
# Computer played Jack of Clubs.
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 73
#
#
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card King of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Queen of Clubs.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 74
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Nine of Diamonds.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 75
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Two of Clubs.
# press ENTER to see what card Computer plays
# Computer played Jack of Spades.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 76
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Clubs.
# press ENTER to see what card Computer plays
# Computer played Queen of Spades.
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 77
#
#
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Clubs.
# press ENTER to see what card Computer plays
# Computer played King of Hearts.
# Juliana holds 30 cards.
# Computer holds 22 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 78
#
#
# Juliana holds 30 cards.
# Computer holds 22 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Spades.
# press ENTER to see what card Computer plays
# Computer played Three of Diamonds.
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 79
#
#
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Two of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Four of Spades.
# Juliana holds 30 cards.
# Computer holds 22 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 80
#
#
# Juliana holds 30 cards.
# Computer holds 22 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Clubs.
# press ENTER to see what card Computer plays
# Computer played Four of Hearts.
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 81
#
#
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card King of Clubs.
# press ENTER to see what card Computer plays
# Computer played Six of Spades.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 82
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Hearts.
# press ENTER to see what card Computer plays
# Computer played Six of Diamonds.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 83
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Spades.
# press ENTER to see what card Computer plays
# Computer played Seven of Spades.
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 84
#
#
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Hearts.
# press ENTER to see what card Computer plays
# Computer played King of Spades.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 85
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Ace of Clubs.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 86
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Hearts.
# press ENTER to see what card Computer plays
# Computer played Four of Clubs.
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 87
#
#
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Hearts.
# press ENTER to see what card Computer plays
# Computer played Nine of Clubs.
#
#  WAR !!!!
#
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 88
#
#
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Two of Hearts.
# press ENTER to see what card Computer plays
# Computer played Jack of Clubs.
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 89
#
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Two of Clubs.
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 90
#
#
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Spades.
# press ENTER to see what card Computer plays
# Computer played Jack of Spades.
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 91
#
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Six of Clubs.
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 92
#
#
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Hearts.
# press ENTER to see what card Computer plays
# Computer played Queen of Spades.
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 93
#
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Hearts.
# press ENTER to see what card Computer plays
# Computer played Seven of Clubs.
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 94
#
#
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Clubs.
# press ENTER to see what card Computer plays
# Computer played King of Hearts.
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 95
#
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Hearts.
# press ENTER to see what card Computer plays
# Computer played Two of Diamonds.
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 96
#
#
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Spades.
# press ENTER to see what card Computer plays
# Computer played Four of Spades.
# Juliana holds 38 cards.
# Computer holds 14 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 97
#
#
# Juliana holds 38 cards.
# Computer holds 14 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Two of Spades.
# press ENTER to see what card Computer plays
# Computer played Jack of Hearts.
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 98
#
#
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Eight of Diamonds.
# press ENTER to see what card Computer plays
# Computer played King of Spades.
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 99
#
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Clubs.
# press ENTER to see what card Computer plays
# Computer played Four of Diamonds.
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 100
#
#
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card King of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Ace of Clubs.
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 101
#
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Three of Hearts.
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 102
#
#
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Four of Clubs.
# Juliana holds 38 cards.
# Computer holds 14 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 103
#
#
# Juliana holds 38 cards.
# Computer holds 14 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Two of Hearts.
# Juliana holds 39 cards.
# Computer holds 13 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 104
#
#
# Juliana holds 39 cards.
# Computer holds 13 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Spades.
# press ENTER to see what card Computer plays
# Computer played Jack of Clubs.
# Juliana holds 40 cards.
# Computer holds 12 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 105
#
#
# Juliana holds 40 cards.
# Computer holds 12 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Hearts.
# press ENTER to see what card Computer plays
# Computer played Three of Spades.
# Juliana holds 41 cards.
# Computer holds 11 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 106
#
#
# Juliana holds 41 cards.
# Computer holds 11 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Clubs.
# press ENTER to see what card Computer plays
# Computer played Jack of Spades.
# Juliana holds 40 cards.
# Computer holds 12 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 107
#
#
# Juliana holds 40 cards.
# Computer holds 12 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Spades.
# press ENTER to see what card Computer plays
# Computer played Five of Hearts.
# Juliana holds 41 cards.
# Computer holds 11 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 108
#
#
# Juliana holds 41 cards.
# Computer holds 11 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card King of Clubs.
# press ENTER to see what card Computer plays
# Computer played Queen of Spades.
# Juliana holds 42 cards.
# Computer holds 10 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 109
#
#
# Juliana holds 42 cards.
# Computer holds 10 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Three of Clubs.
# Juliana holds 43 cards.
# Computer holds 9 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 110
#
#
# Juliana holds 43 cards.
# Computer holds 9 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Hearts.
# press ENTER to see what card Computer plays
# Computer played King of Hearts.
# Juliana holds 44 cards.
# Computer holds 8 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 111
#
#
# Juliana holds 44 cards.
# Computer holds 8 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Spades.
# press ENTER to see what card Computer plays
# Computer played Two of Spades.
# Juliana holds 45 cards.
# Computer holds 7 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 112
#
#
# Juliana holds 45 cards.
# Computer holds 7 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Spades.
# press ENTER to see what card Computer plays
# Computer played Jack of Hearts.
# Juliana holds 44 cards.
# Computer holds 8 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 113
#
#
# Juliana holds 44 cards.
# Computer holds 8 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Clubs.
# press ENTER to see what card Computer plays
# Computer played Eight of Diamonds.
# Juliana holds 45 cards.
# Computer holds 7 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 114
#
#
# Juliana holds 45 cards.
# Computer holds 7 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Spades.
# press ENTER to see what card Computer plays
# Computer played King of Spades.
# Juliana holds 44 cards.
# Computer holds 8 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 115
#
#
# Juliana holds 44 cards.
# Computer holds 8 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Hearts.
# press ENTER to see what card Computer plays
# Computer played King of Diamonds.
# Juliana holds 43 cards.
# Computer holds 9 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 116
#
#
# Juliana holds 43 cards.
# Computer holds 9 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Eight of Hearts.
# press ENTER to see what card Computer plays
# Computer played Ace of Clubs.
# Juliana holds 42 cards.
# Computer holds 10 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 117
#
#
# Juliana holds 42 cards.
# Computer holds 10 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Hearts.
# press ENTER to see what card Computer plays
# Computer played Ten of Clubs.
#
#  WAR !!!!
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 118
#
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Eight of Clubs.
# press ENTER to see what card Computer plays
# Computer played Six of Hearts.
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 119
#
#
# Juliana holds 37 cards.
# Computer holds 15 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Diamonds.
# press ENTER to see what card Computer plays
# Computer played King of Diamonds.
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 120
#
#
# Juliana holds 36 cards.
# Computer holds 16 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Two of Clubs.
# press ENTER to see what card Computer plays
# Computer played Eight of Hearts.
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 121
#
#
# Juliana holds 35 cards.
# Computer holds 17 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Ace of Clubs.
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 122
#
#
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Clubs.
# press ENTER to see what card Computer plays
# Computer played Ten of Hearts.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 123
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Five of Clubs.
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 124
#
#
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Clubs.
# press ENTER to see what card Computer plays
# Computer played Nine of Hearts.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 125
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Hearts.
# press ENTER to see what card Computer plays
# Computer played Eight of Spades.
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 126
#
#
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Two of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Jack of Diamonds.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 127
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Hearts.
# press ENTER to see what card Computer plays
# Computer played Five of Diamonds.
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 128
#
#
# Juliana holds 34 cards.
# Computer holds 18 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Spades.
# press ENTER to see what card Computer plays
# Computer played Ten of Clubs.
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 129
#
#
# Juliana holds 33 cards.
# Computer holds 19 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Spades.
# press ENTER to see what card Computer plays
# Computer played Jack of Spades.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 130
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Ten of Spades.
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 131
#
#
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Clubs.
# press ENTER to see what card Computer plays
# Computer played Jack of Hearts.
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 132
#
#
# Juliana holds 32 cards.
# Computer holds 20 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Hearts.
# press ENTER to see what card Computer plays
# Computer played Five of Spades.
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 133
#
#
# Juliana holds 31 cards.
# Computer holds 21 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Diamonds.
# press ENTER to see what card Computer plays
# Computer played King of Spades.
# Juliana holds 30 cards.
# Computer holds 22 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 134
#
#
# Juliana holds 30 cards.
# Computer holds 22 cards.
#
# It is time to play !
# press ENTER to play a card
# ...
# Computer played Seven of Spades.
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 223
#
#
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Hearts.
# press ENTER to see what card Computer plays
# Computer played King of Clubs.
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 224
#
#
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card King of Spades.
# press ENTER to see what card Computer plays
# Computer played Five of Spades.
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 225
#
#
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Clubs.
# press ENTER to see what card Computer plays
# Computer played Seven of Diamonds.
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 226
#
#
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Hearts.
# press ENTER to see what card Computer plays
# Computer played Six of Spades.
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 227
#
#
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Nine of Spades.
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 228
#
#
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Clubs.
# press ENTER to see what card Computer plays
# Computer played Three of Spades.
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 229
#
#
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Diamonds.
# press ENTER to see what card Computer plays
# Computer played King of Hearts.
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 230
#
#
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Eight of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Ten of Spades.
# Juliana holds 14 cards.
# Computer holds 38 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 231
#
#
# Juliana holds 14 cards.
# Computer holds 38 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Eight of Hearts.
# press ENTER to see what card Computer plays
# Computer played Queen of Spades.
# Juliana holds 13 cards.
# Computer holds 39 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 232
#
#
# Juliana holds 13 cards.
# Computer holds 39 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Six of Hearts.
# Juliana holds 14 cards.
# Computer holds 38 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 233
#
#
# Juliana holds 14 cards.
# Computer holds 38 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Ace of Clubs.
# Juliana holds 13 cards.
# Computer holds 39 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 234
#
#
# Juliana holds 13 cards.
# Computer holds 39 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Clubs.
# press ENTER to see what card Computer plays
# Computer played Nine of Clubs.
# Juliana holds 14 cards.
# Computer holds 38 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 235
#
#
# Juliana holds 14 cards.
# Computer holds 38 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Jack of Spades.
# Juliana holds 13 cards.
# Computer holds 39 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 236
#
#
# Juliana holds 13 cards.
# Computer holds 39 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Spades.
# press ENTER to see what card Computer plays
# Computer played Queen of Diamonds.
# Juliana holds 14 cards.
# Computer holds 38 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 237
#
#
# Juliana holds 14 cards.
# Computer holds 38 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Spades.
# press ENTER to see what card Computer plays
# Computer played Four of Hearts.
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 238
#
#
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ten of Hearts.
# press ENTER to see what card Computer plays
# Computer played Ace of Diamonds.
# Juliana holds 14 cards.
# Computer holds 38 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 239
#
#
# Juliana holds 14 cards.
# Computer holds 38 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Spades.
# press ENTER to see what card Computer plays
# Computer played Two of Clubs.
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 240
#
#
# Juliana holds 15 cards.
# Computer holds 37 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card King of Spades.
# press ENTER to see what card Computer plays
# Computer played Four of Spades.
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 241
#
#
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Spades.
# press ENTER to see what card Computer plays
# Computer played Two of Diamonds.
# Juliana holds 17 cards.
# Computer holds 35 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 242
#
#
# Juliana holds 17 cards.
# Computer holds 35 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Hearts.
# press ENTER to see what card Computer plays
# Computer played Ten of Clubs.
# Juliana holds 18 cards.
# Computer holds 34 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 243
#
#
# Juliana holds 18 cards.
# Computer holds 34 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Spades.
# press ENTER to see what card Computer plays
# Computer played Four of Diamonds.
# Juliana holds 17 cards.
# Computer holds 35 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 244
#
#
# Juliana holds 17 cards.
# Computer holds 35 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Clubs.
# press ENTER to see what card Computer plays
# Computer played Eight of Spades.
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 245
#
#
# Juliana holds 16 cards.
# Computer holds 36 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Hearts.
# press ENTER to see what card Computer plays
# Computer played Two of Spades.
# Juliana holds 17 cards.
# Computer holds 35 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 246
#
#
# Juliana holds 17 cards.
# Computer holds 35 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Seven of Hearts.
# Juliana holds 18 cards.
# Computer holds 34 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 247
#
#
# Juliana holds 18 cards.
# Computer holds 34 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Clubs.
# press ENTER to see what card Computer plays
# Computer played Three of Hearts.
# Juliana holds 19 cards.
# Computer holds 33 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 248
#
#
# Juliana holds 19 cards.
# Computer holds 33 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Clubs.
# press ENTER to see what card Computer plays
# Computer played Jack of Hearts.
# Juliana holds 20 cards.
# Computer holds 32 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 249
#
#
# Juliana holds 20 cards.
# Computer holds 32 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Four of Clubs.
# Juliana holds 21 cards.
# Computer holds 31 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 250
#
#
# Juliana holds 21 cards.
# Computer holds 31 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Spades.
# press ENTER to see what card Computer plays
# Computer played Jack of Clubs.
# Juliana holds 22 cards.
# Computer holds 30 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 251
#
#
# Juliana holds 22 cards.
# Computer holds 30 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Hearts.
# press ENTER to see what card Computer plays
# Computer played Six of Clubs.
# Juliana holds 21 cards.
# Computer holds 31 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 252
#
#
# Juliana holds 21 cards.
# Computer holds 31 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Spades.
# press ENTER to see what card Computer plays
# Computer played Queen of Hearts.
# Juliana holds 20 cards.
# Computer holds 32 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 253
#
#
# Juliana holds 20 cards.
# Computer holds 32 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Two of Clubs.
# press ENTER to see what card Computer plays
# Computer played Five of Clubs.
# Juliana holds 19 cards.
# Computer holds 33 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 254
#
#
# Juliana holds 19 cards.
# Computer holds 33 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Five of Spades.
# press ENTER to see what card Computer plays
# Computer played Jack of Diamonds.
# Juliana holds 18 cards.
# Computer holds 34 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 255
#
#
# Juliana holds 18 cards.
# Computer holds 34 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Four of Spades.
# press ENTER to see what card Computer plays
# Computer played Eight of Clubs.
# Juliana holds 17 cards.
# Computer holds 35 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 256
#
#
# Juliana holds 17 cards.
# Computer holds 35 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card King of Spades.
# press ENTER to see what card Computer plays
# Computer played King of Diamonds.
#
#  WAR !!!!
#
# Juliana holds 11 cards.
# Computer holds 41 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 257
#
#
# Juliana holds 11 cards.
# Computer holds 41 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Hearts.
# press ENTER to see what card Computer plays
# Computer played Seven of Diamonds.
# Juliana holds 10 cards.
# Computer holds 42 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 258
#
#
# Juliana holds 10 cards.
# Computer holds 42 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Hearts.
# press ENTER to see what card Computer plays
# Computer played Six of Diamonds.
# Juliana holds 11 cards.
# Computer holds 41 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 259
#
#
# Juliana holds 11 cards.
# Computer holds 41 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Nine of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Nine of Spades.
#
#  WAR !!!!
#
# Juliana holds 5 cards.
# Computer holds 47 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 260
#
#
# Juliana holds 5 cards.
# Computer holds 47 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Queen of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Queen of Spades.
#
#  WAR !!!!
#
# Juliana unable to declare war
# Computer WINS !
#
#
# 	----------------------------------------------------------------------------
# 	Round 261
#
#
# Juliana holds 4 cards.
# Computer holds 46 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Clubs.
# press ENTER to see what card Computer plays
# Computer played Three of Diamonds.
# Juliana holds 5 cards.
# Computer holds 45 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 262
#
#
# Juliana holds 5 cards.
# Computer holds 45 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Ace of Spades.
# press ENTER to see what card Computer plays
# Computer played Ace of Clubs.
#
#  WAR !!!!
#
# Juliana unable to declare war
# Computer WINS !
#
#
# 	----------------------------------------------------------------------------
# 	Round 263
#
#
# Juliana holds 4 cards.
# Computer holds 44 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Six of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Ten of Diamonds.
# Juliana holds 3 cards.
# Computer holds 45 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 264
#
#
# Juliana holds 3 cards.
# Computer holds 45 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Seven of Hearts.
# press ENTER to see what card Computer plays
# Computer played Jack of Spades.
# Juliana holds 2 cards.
# Computer holds 46 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 265
#
#
# Juliana holds 2 cards.
# Computer holds 46 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Three of Diamonds.
# press ENTER to see what card Computer plays
# Computer played Ten of Hearts.
# Juliana holds 1 cards.
# Computer holds 47 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 266
#
#
# Juliana holds 1 cards.
# Computer holds 47 cards.
#
# It is time to play !
# press ENTER to play a card
# You played the card Jack of Clubs.
# press ENTER to see what card Computer plays
# Computer played Ace of Diamonds.
# Juliana holds 0 cards.
# Computer holds 48 cards.
#
#
# 	----------------------------------------------------------------------------
# 	Round 267
#
#
# Juliana holds 0 cards.
# Computer holds 48 cards.
# Juliana, you don't have any card left. Computer wins !
